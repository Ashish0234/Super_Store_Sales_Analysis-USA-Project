# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel(r"/Users/ashishkumar/Downloads/P1-SuperStoreUS-2015.xlsx")

# %%
df.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
#
#     Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0   Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1  Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2   Marcus Dunlap     Regular Air      Home Office        Furniture  ...
#
#   Region State or Province         City  Postal Code Order Date  Ship Date  \
# 0   West        Washington    Anacortes        98221 2015-01-07 2015-01-08
# 1   West        California  San Gabriel        91776 2015-06-13 2015-06-15
# 2   East        New Jersey      Roselle         7203 2015-02-15 2015-02-17
#
#       Profit Quantity ordered new    Sales Order ID
# ...

# %%
df.shape
# Out:
# (1952, 25)

# %%
df.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
df['Product Base Margin'].fillna(df['Product Base Margin'].mean(),inplace=True)

# %% [markdown]
# # Order Priority

# %%
df['Order Priority'].unique()
# Out:
# array(['High', 'Not Specified', 'Critical', 'Medium', 'Low', 'Critical '],
#       dtype=object)

# %%
df['Order Priority'].replace('Critical ','Critical')
# Out:
# 0                High
# 1       Not Specified
# 2            Critical
# 3              Medium
# 4              Medium
#             ...
# 1947             High
# 1948             High
# 1949    Not Specified
# 1950           Medium
# 1951             High
# Name: Order Priority, Length: 1952, dtype: object

# %%
df['Order Priority']=df['Order Priority'].replace('Critical ','Critical')

# %%
df['Order Priority'].nunique()
# Out:
# 5

# %%
df['Order Priority'].value_counts()
# Out:
# Order Priority
# Low              398
# Not Specified    396
# High             391
# Critical         391
# Medium           376
# Name: count, dtype: int64

# %%
plt.title('Count of Order Priority')
sns.countplot(x="Order Priority",data=df)
plt.figure(figsize=(4,2))
plt.show()

# %% [markdown]
# # Shipping Mode

# %%
df['Ship Mode'].nunique()
# Out:
# 3

# %%
df['Ship Mode'].unique()
# Out:
# array(['Express Air', 'Delivery Truck', 'Regular Air'], dtype=object)

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Regular Air       1437
# Delivery Truck     275
# Express Air        240
# Name: count, dtype: int64

# %% [markdown]
# # SHIP MODE visualization through pie chat

# %%
x=df['Ship Mode'].value_counts().index
y=df['Ship Mode'].value_counts().values

# %%
plt.figure(figsize=(7,5))
plt.pie(y,labels=x,autopct="%0.2f%%")
plt.legend()
plt.show()

# %% [markdown]
# # Ship Mode visualization on the basis of Product Category

# %%
plt.title("Ship Mode")
sns.countplot(x="Ship Mode",data=df,hue="Product Category")
plt.figure(figsize=(5,3))
plt.show()

# %% [markdown]
# # Customer Segment

# %%
df['Customer Segment'].nunique()
# Out:
# 4

# %%
df['Customer Segment'].unique()
# Out:
# array(['Corporate', 'Home Office', 'Small Business', 'Consumer'],
#       dtype=object)

# %%
plt.title("Customer Segment")
sns.countplot(x="Customer Segment",data=df)
plt.figure(figsize=(5,3))
plt.show()

# %% [markdown]
# # Product Category

# %%
df['Product Category'].nunique()
# Out:
# 3

# %%
df['Product Category'].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
df['Product Category'].value_counts()
# Out:
# Product Category
# Office Supplies    1071
# Technology          481
# Furniture           400
# Name: count, dtype: int64

# %%
plt.title("Product Category")
sns.countplot(x="Product Category",data=df)
plt.figure(figsize=(5,3))
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1952 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
df['Order Date'].dt.year
# Out:
# 0       2015
# 1       2015
# 2       2015
# 3       2015
# 4       2015
#         ...
# 1947    2015
# 1948    2015
# 1949    2015
# 1950    2015
# 1951    2015
# Name: Order Date, Length: 1952, dtype: int32

# %%
df['Ship Date']=df['Ship Date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1952 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
df['Ship Date'].value_counts()
# Out:
# Ship Date
# 2015    1952
# Name: count, dtype: int64

# %% [markdown]
# # Profit on the basis of Product Category

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="Product Category",y="Profit",data=df,estimator="sum")
plt.show()

# %% [markdown]
# # Top 5 States or Provinces

# %%
df['State or Province'].value_counts()[:5]
# Out:
# State or Province
# California    214
# New York      129
# Texas         124
# Florida       123
# Illinois       88
# Name: count, dtype: int64

# %%
top_states=df['State or Province'].value_counts()[:5]

# %%
plt.figure(figsize=(10, 6))
top_states.plot(kind='bar')
plt.title('Top 5 States or Provinces by Count')
plt.xlabel('State or Province')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Product Container

# %%
df['Product Container'].nunique()
# Out:
# 7

# %%
df['Product Container'].unique()
# Out:
# array(['Wrap Bag', 'Jumbo Drum', 'Small Pack', 'Small Box', 'Medium Box',
#        'Jumbo Box', 'Large Box'], dtype=object)

# %%
plt.figure(figsize=(12, 6))

sns.countplot(x="Product Container", data=df)

plt.title("Product Container")

# Rotate x-tick labels
plt.xticks(rotation=45)
plt.show()
